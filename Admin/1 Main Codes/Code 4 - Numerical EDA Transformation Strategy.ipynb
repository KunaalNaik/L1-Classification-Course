# %% [markdown]
# # Code 4
# - Numerical EDA
#   - Basic Transforrmation
# - Logistic Model (Balanced/ Unbalanced)

# %% [markdown]
# ## 1/ Import Libraries

# %%
#CodeSection1
from google.colab import drive
drive.mount('/mntDrive')
# Out:
# Drive already mounted at /mntDrive; to attempt to forcibly remount, call drive.mount("/mntDrive", force_remount=True).

# %%
#CodeSection2
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2/ Import Data

# %%
#CodeSection3
train = pd.read_csv('/mntDrive/MyDrive/Project MasterMind/1 - Planning Stage/2- Research/6- New Teaching Method/Loan Prediction (Webinar Flow)/Solution Codes/input/train.csv')
test = pd.read_csv('/mntDrive/MyDrive/Project MasterMind/1 - Planning Stage/2- Research/6- New Teaching Method/Loan Prediction (Webinar Flow)/Solution Codes/input/test.csv')

# %% [markdown]
# ## 3/ Combine both Datasets (train, test)

# %%
#CodeSection4
all_data = [train, test]

# %% [markdown]
# ### Check Combined Data
# - Missing Value
# - Data Types

# %%
#CodeSection5
# Combine both to check Missing Value
pd.concat([train, test], axis = 0).isnull().sum()
# Out:
# Loan_ID                0
# Gender                24
# Married                3
# Dependents            25
# Education              0
# Self_Employed         55
# ApplicantIncome        2
# CoapplicantIncome      0
# LoanAmount            27
# Loan_Amount_Term      20
# Credit_History        79
# Property_Area          0
# Loan_Status          367
# dtype: int64

# %%
#CodeSection6
# Check Data types for each variable
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# ## 4/ EDA - Check Numerical Variables

# %%
#CodeSection7
# Lets Import the Seaborn Library
import seaborn as sns

# %% [markdown]
# ### Lets start with Numerical Variable/Feature - 1

# %%
#CodeSection8
# in this case we start with "ApplicantIncome"
# Use Histplot to check if its a normal distribution
sns.histplot(train['ApplicantIncome']) 
# Not Normal

# %%
#Check other variables too and transform if needed

# %% [markdown]
# ### Log Transformation
# - Transform a Numerical Feature to Normal

# %%
#CodeSection9
# Use np.log to tranform make your feature normal
feature_normal = np.log(train['ApplicantIncome'])

# Plot Normal Distribution
sns.histplot(feature_normal)

# %% [markdown]
# ### Now lets Tranform One Variable/Feature

# %%
#CodeSection10
# Write the Transformation Code
for dataset in all_data:
  dataset['ApplicantIncome'] = np.log(dataset['ApplicantIncome'] + 1) # "1" is added to avoid error for rows that contain "0"

# %%
#CodeSection11
# Lets check again
sns.histplot(train['ApplicantIncome']) 
# Normal Distribution

# %% [markdown]
# ### Replicate for other Numerical Variable/Features

# %%
#CodeSection12

# Identify all other Numerical Variables 
numerical_features = ['CoapplicantIncome','LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# Write a loop to do the same
for num_var in numerical_features:
  for dataset in all_data:
    dataset[num_var] = np.log(dataset[num_var] + 1)

# %% [markdown]
# ## 5/ Impute Numerical Variables

# %% [markdown]
# ### Impute all Numerical Variables at once

# %%
#CodeSection13
# Write a loop to Impute all Numerical Vairbales
for dataset in all_data:
  # Numerical Feature 1
  dataset['ApplicantIncome'] = dataset['ApplicantIncome'].fillna(dataset['ApplicantIncome'].median())
  
  # Numerical Feature 2
  dataset['CoapplicantIncome'] = dataset['CoapplicantIncome'].fillna(dataset['CoapplicantIncome'].median())

  # Numerical Feature 3
  dataset['LoanAmount'] = dataset['LoanAmount'].fillna(dataset['LoanAmount'].median())
  
  # Numerical Feature 5
  dataset['Loan_Amount_Term'] = dataset['Loan_Amount_Term'].fillna(dataset['Loan_Amount_Term'].median())

  # Numerical Feature 6
  dataset['Credit_History'] = dataset['Credit_History'].fillna(dataset['Credit_History'].median())

# %% [markdown]
# ## 6/ Impute Categorical Variables
# - Lets try another Strategy of Imputing "Missing" where a Category value is missing

# %% [markdown]
# ### Impute all Categorical Variables at once

# %%
#CodeSection14
for dataset in all_data:
  # Categorical Feature 1
  dataset['Gender'] = dataset['Gender'].fillna('Missing')

  # Categorical Feature 2
  dataset['Married'] = dataset['Married'].fillna('Missing')
  
  # Categorical Feature 3
  dataset['Dependents'] = dataset['Dependents'].fillna('Missing')

  # Categorical Feature 4
  dataset['Self_Employed'] = dataset['Self_Employed'].fillna('Missing')

# %% [markdown]
# ## 7/ Now Re Check all Features

# %%
#CodeSection15
# Combine both to check Missing Value
pd.concat([train, test], axis = 0).isnull().sum()
# Out:
# Loan_ID                0
# Gender                 0
# Married                0
# Dependents             0
# Education              0
# Self_Employed          0
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount             0
# Loan_Amount_Term       0
# Credit_History         0
# Property_Area          0
# Loan_Status          367
# dtype: int64

# %% [markdown]
# ## 8/ Prepare Data for Model Model

# %%
#CodeSection16
# Check First 5 Rows of Test Data
test.head()
# Out:
#     Loan_ID Gender Married  ... Loan_Amount_Term Credit_History Property_Area
# 0  LP001015   Male     Yes  ...         5.888878       0.693147         Urban
# 1  LP001022   Male     Yes  ...         5.888878       0.693147         Urban
# 2  LP001031   Male     Yes  ...         5.888878       0.693147         Urban
# 3  LP001035   Male     Yes  ...         5.888878       0.693147         Urban
# 4  LP001051   Male      No  ...         5.888878       0.693147         Urban
#
# [5 rows x 12 columns]

# %%
#CodeSection17
# Get X and y Variables for your Dataset
X = train.drop(['Loan_Status','Loan_ID'], axis =  1)
y = train['Loan_Status']

# %% [markdown]
# ### Create Dummy Variables for  Categorical Variables

# %%
#CodeSection18
# Get Dummy Variables
X = pd.get_dummies(X)  # Keep only n - 1 Variables - Use "drop_first = True"

# %% [markdown]
# ## 9/ Build Model

# %%
#CodeSection19
#Import Logistic Regression Library
from sklearn.linear_model import LogisticRegression

#Initialize LR
clf = LogisticRegression(max_iter = 1000)

# %%
#CodeSection20
# Fit Model
model = clf.fit(X, y)

# %% [markdown]
# ### Check Accuracy of Model on Train Data

# %%
#CodeSection21
# Predict on Train Data
y_pred = model.predict(X)

# %% [markdown]
# ### We can use a Accuracy Function from Metrics
# - Check Train Accuracy

# %%
#CodeSection22
# Import metrics library
from sklearn.metrics import accuracy_score

# %%
#CodeSection23
# get Actual "y" variables (use "y_true" as variable)
y_true = train['Loan_Status']

# %%
#CodeSection24
# Print Train Accuracy
print(f" Train Accuracy : {accuracy_score(y_true, y_pred):0.1%}")
# Out:
#  Train Accuracy : 80.9%

# %% [markdown]
# ## 10/ Predict & Submit

# %% [markdown]
# ### Predict

# %%
#CodeSection25
# Get all the X Variables from the Test Dataset
X_test = test.drop(['Loan_ID'], axis =  1)

# %%
#CodeSection26
#Covert to Dummies
X_test = pd.get_dummies(X_test)

# %%
#CodeSection27
# use this code if the next Code shows error
#X_test['Married_Missing']  = 0

# %%
#CodeSection28
# Predict on X_test Data ("X_test_prep")
X_test_prep = model.predict(X_test)

# %% [markdown]
# ### Import Sample Submission

# %%
#CodeSection29
sample_submission = pd.read_csv('/mntDrive/MyDrive/Project MasterMind/1 - Planning Stage/2- Research/6- New Teaching Method/Loan Prediction (Webinar Flow)/Solution Codes/input/sample_submission.csv')
sample_submission.head()
# Out:
#     Loan_ID Loan_Status
# 0  LP001015           N
# 1  LP001022           N
# 2  LP001031           N
# 3  LP001035           N
# 4  LP001051           N

# %% [markdown]
# ### Create Submission File

# %%
#CodeSection30
submission = pd.DataFrame({
    'Loan_ID' : test['Loan_ID'],
    'Loan_Status' : X_test_prep
})

# %% [markdown]
# ### Export Submission File

# %%
#CodeSection31
submission.to_csv('/mntDrive/MyDrive/Project MasterMind/1 - Planning Stage/2- Research/6- New Teaching Method/Loan Prediction (Webinar Flow)/Solution Codes/output/O4_Transformation_Strategy.csv', index = False)

# %%
# LB Accuracy : 0.7777
