# %% [markdown]
# # Code 2
# - Basic Imputation for Numerical and Categorial
# - Logistic Model (Balanced/ Unbalanced)

# %% [markdown]
# ## 1/ Import Libraries

# %%
#CodeSection1
from google.colab import drive
drive.mount('/mntDrive')
# Out:
# Mounted at /mntDrive

# %%
#CodeSection2
import pandas as pd

# %% [markdown]
# ## 2/ Import Data

# %%
#CodeSection3
train = pd.read_csv('/mntDrive/MyDrive/Project MasterMind/1 - Planning Stage/2- Research/6- New Teaching Method/Loan Prediction (Webinar Flow)/Solution Codes/input/train.csv')
test = pd.read_csv('/mntDrive/MyDrive/Project MasterMind/1 - Planning Stage/2- Research/6- New Teaching Method/Loan Prediction (Webinar Flow)/Solution Codes/input/test.csv')

# %% [markdown]
# ### Check Train Data

# %%
#CodeSection4
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# ### Check Test Data

# %%
#CodeSection4
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    365 non-null    float64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 34.5+ KB

# %% [markdown]
# ### We Combine both Datasets to perform Missing Value Imputation

# %%
#CodeSection6
all_data = [train, test]

# %%
#CodeSection7
# Combine both using concat (with axis = 0) to check Missing Value
pd.concat([train, test], axis = 0).isnull().sum()
# Out:
# Loan_ID                0
# Gender                24
# Married                3
# Dependents            25
# Education              0
# Self_Employed         55
# ApplicantIncome        2
# CoapplicantIncome      0
# LoanAmount            27
# Loan_Amount_Term      20
# Credit_History        79
# Property_Area          0
# Loan_Status          367
# dtype: int64

# %% [markdown]
# ## 3/ Impute Numerical Variables
# - Impute all Numerical Variables

# %% [markdown]
# ### Variable/Feature 1

# %%
#CodeSection8
# Impute Feature with mean/median for both train and test - use for loop
#ApplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History
for dataset in all_data:
  dataset['ApplicantIncome'] = dataset['ApplicantIncome'].fillna(train['ApplicantIncome'].median())

# %% [markdown]
# ### Variable/Feature 2

# %%
#CodeSection8
# Impute Feature with mean/median for both train and test - use for loop
for dataset in all_data:
  dataset['LoanAmount'] = dataset['LoanAmount'].fillna(train['LoanAmount'].median())

# %% [markdown]
# ### Variable/Feature 3

# %%
#CodeSection8
# Impute Feature with mean/median for both train and test - use for loop
for dataset in all_data:
  dataset['Loan_Amount_Term'] = dataset['Loan_Amount_Term'].fillna(train['Loan_Amount_Term'].median())

# %% [markdown]
# ### Variable/Feature 4

# %%
#CodeSection8
# Impute Feature with mean/median for both train and test - use for loop
for dataset in all_data:
  dataset['Credit_History'] = dataset['Credit_History'].fillna(train['Credit_History'].median())

# %% [markdown]
# ## 4/ Impute Categorical Variables
# - Impute all Numerical Variables

# %% [markdown]
# ### Categorical Variable/Feature 1

# %%
#CodeSection9
# Impute Feature with mode (use [0]) for both train and test - use for loop
#Gender , Married , Dependents , Self_Employed 
for dataset in all_data:
  dataset['Gender'] = dataset['Gender'].fillna(train['Gender'].mode()[0])

# %% [markdown]
# ### Categorical Variable/Feature 2

# %%
#CodeSection9
# Impute Feature with mode (use [0]) for both train and test - use for loop
for dataset in all_data:
  dataset['Married'] = dataset['Married'].fillna(train['Married'].mode()[0])

# %% [markdown]
# ### Categorical Variable/Feature 3

# %%
#CodeSection9
# Impute Feature with mode (use [0]) for both train and test - use for loop
for dataset in all_data:
  dataset['Dependents'] = dataset['Dependents'].fillna(train['Dependents'].mode()[0])

# %% [markdown]
# ### Categorical Variable/Feature 4

# %%
#CodeSection9
# Impute Feature with mode (use [0]) for both train and test - use for loop
for dataset in all_data:
  dataset['Self_Employed'] = dataset['Self_Employed'].fillna(train['Self_Employed'].mode()[0])

# %% [markdown]
# ## 5/ Now Re Check all of them

# %%
#CodeSection10
# Combine both to check Missing Value
pd.concat([train, test], axis = 0).isnull().sum()
# Out:
# Loan_ID                0
# Gender                 0
# Married                0
# Dependents             0
# Education              0
# Self_Employed          0
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount             0
# Loan_Amount_Term       0
# Credit_History         0
# Property_Area          0
# Loan_Status          367
# dtype: int64

# %% [markdown]
# ## 6/ Prepare Data for Model Model

# %%
#CodeSection11
# Check first 5 rows of Test Dataset
train.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
#CodeSection12
# Divide Data into X and y
X = train.drop(['Loan_ID','Loan_Status'], axis = 1)
y = train['Loan_Status']

# %% [markdown]
# ### Create Dummy Variables for  Categorical Variables

# %%
#CodeSection13
# Create Dummy Variables
X = pd.get_dummies(X)

# %%
#CodeSection14
# Check first 5 rows of X
X.head()
# Out:
#    ApplicantIncome  ...  Property_Area_Urban
# 0             5849  ...                    1
# 1             4583  ...                    0
# 2             3000  ...                    1
# 3             2583  ...                    1
# 4             6000  ...                    1
#
# [5 rows x 20 columns]

# %% [markdown]
# ## 7/ Build Model

# %%
#CodeSection15
#Start by importing LogisticRegression 
from sklearn.linear_model import LogisticRegression

#Initialize LogisticRegression
clf = LogisticRegression(max_iter=1000)

# %%
#CodeSection16
# Fit Model
model = clf.fit(X, y)

# %% [markdown]
# ### Check Accuracy of Model on Train Data

# %%
#CodeSection17
# Predict on Train Data and check predictions
y_pred = model.predict(X)
y_pred
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'N',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N'], dtype=object)

# %% [markdown]
# ### We can use a Accuracy Function from Metrics

# %%
#CodeSection17
# Import accuracy_score 
from sklearn.metrics import accuracy_score

# %%
#CodeSection18
# Get Actual Predictions
y_true = train['Loan_Status']

# %%
#CodeSection19
# Compare True values versus prediction we made
print(f" Train Accuracy : {accuracy_score(y_true, y_pred):0.1%}")
# Out:
#  Train Accuracy : 81.1%

# %% [markdown]
# ## 8/ Prediction and Submission

# %% [markdown]
# ### Predict

# %%
#CodeSection20
# Get X variables from the Test Dataset
X_test = test.drop('Loan_ID', axis = 1)

# %%
#CodeSection21
#Covert to Dummies
X_test = pd.get_dummies(X_test)

# %%
#CodeSection22
# Predict (Y/N) on X Variables of Test Dataset
X_test_prep = model.predict(X_test)

# %% [markdown]
# ### Import Sample Submission

# %%
#CodeSection23
sample_submission = pd.read_csv('/mntDrive/MyDrive/Project MasterMind/1 - Planning Stage/2- Research/6- New Teaching Method/Loan Prediction (Webinar Flow)/Solution Codes/input/sample_submission.csv')
sample_submission.head()
# Out:
#     Loan_ID Loan_Status
# 0  LP001015           N
# 1  LP001022           N
# 2  LP001031           N
# 3  LP001035           N
# 4  LP001051           N

# %% [markdown]
# ### Create a Submission

# %%
#CodeSection24
submission = pd.DataFrame({
    'Loan_ID' : test['Loan_ID'],
    'Loan_Status' : X_test_prep
})

# %% [markdown]
# ### Export Submission File

# %%
#CodeSection25
submission.to_csv('/mntDrive/MyDrive/Project MasterMind/1 - Planning Stage/2- Research/6- New Teaching Method/Loan Prediction (Webinar Flow)/Solution Codes/output/O2_LR_Basic_Impute.csv', index = False)

# %%
# LB Accuracy : 0.7777
